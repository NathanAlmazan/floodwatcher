# %% [markdown]
# # RiverCast

# %% [markdown]
# ## Import Libraries and Dataset

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
# import dataset
df = pd.read_csv('dataset.csv')
df.dropna(inplace=True)
df.head(10)
# Out:
#   Station  Year    Month  Day  Hour  Waterlevel Station.1  Year.1  Month.1  \
# 0  NANGKA  2012  January    1     1       15.86  STO.NINO    2012  January
# 1  NANGKA  2012  January    1     2       15.86  STO.NINO    2012  January
# 2  NANGKA  2012  January    1     3       15.86  STO.NINO    2012  January
# 3  NANGKA  2012  January    1     4       15.86  STO.NINO    2012  January
# 4  NANGKA  2012  January    1     5       15.86  STO.NINO    2012  January
# 5  NANGKA  2012  January    1     6       15.86  STO.NINO    2012  January
# 6  NANGKA  2012  January    1     7       15.86  STO.NINO    2012  January
# 7  NANGKA  2012  January    1     8       15.86  STO.NINO    2012  January
# 8  NANGKA  2012  January    1     9       15.86  STO.NINO    2012  January
# 9  NANGKA  2012  January    1    10       15.86  STO.NINO    2012  January
#
#    Day.1  ...  RF-Intensity.1  Humidity  Precipitation Temperature  \
# 0      1  ...             0.0     18.01           0.01       24.69
# 1      1  ...             0.0     18.01           0.01       24.69
# 2      1  ...             0.0     18.01           0.01       24.69
# 3      1  ...             0.0     18.01           0.01       24.69
# 4      1  ...             0.0     18.01           0.01       24.69
# 5      1  ...             0.0     18.01           0.01       24.69
# 6      1  ...             0.0     18.01           0.01       24.69
# 7      1  ...             0.0     18.01           0.01       24.69
# 8      1  ...             0.0     17.64           0.01       26.20
# 9      1  ...             0.0     17.27           0.02       27.55
#
#    Temperature.1 Humidity.1  Precipitation.1  Temperature.2  Humidity.2  \
# 0          24.69      18.01             0.01          24.69       18.01
# 1          24.69      18.01             0.01          24.69       18.01
# 2          24.69      18.01             0.01          24.69       18.01
# 3          24.69      18.01             0.01          24.69       18.01
# 4          24.69      18.01             0.01          24.69       18.01
# 5          24.69      18.01             0.01          24.69       18.01
# 6          24.69      18.01             0.01          24.69       18.01
# 7          24.69      18.01             0.01          24.69       18.01
# 8          26.20      17.64             0.01          26.20       17.64
# 9          27.55      17.27             0.02          27.55       17.27
#
#   Precipitation.2
# 0            0.01
# 1            0.01
# 2            0.01
# 3            0.01
# 4            0.01
# 5            0.01
# 6            0.01
# 7            0.01
# 8            0.01
# 9            0.02
#
# [10 rows x 32 columns]

# %%
# remove non numeric fields
df = df[['Waterlevel', 'Waterlevel.1', 'Waterlevel.2', 'Waterlevel.3', 'RF-Intensity', 'RF-Intensity.1', 'Temperature', 'Temperature.1',  'Temperature.2', 'Humidity', 'Humidity.1', 'Humidity.2', 'Precipitation', 'Precipitation.1', 'Precipitation.2']]
df = df.astype(np.float64)  # make sure that all data are float type
df.head(10)
# Out:
#    Waterlevel  Waterlevel.1  Waterlevel.2  Waterlevel.3  RF-Intensity  \
# 0       15.86         12.53         12.53         21.97           0.0
# 1       15.86         12.53         12.53         21.97           0.0
# 2       15.86         12.53         12.53         21.97           0.0
# 3       15.86         12.53         12.53         21.97           0.0
# 4       15.86         12.53         12.53         21.97           0.0
# 5       15.86         12.53         12.53         21.97           0.0
# 6       15.86         12.53         12.53         21.97           0.0
# 7       15.86         12.53         12.53         21.97           0.0
# 8       15.86         12.53         12.53         21.97           0.0
# 9       15.86         12.53         12.53         21.97           0.0
#
#    RF-Intensity.1  Temperature  Temperature.1  Temperature.2  Humidity  \
# 0             0.0        24.69          24.69          24.69     18.01
# 1             0.0        24.69          24.69          24.69     18.01
# 2             0.0        24.69          24.69          24.69     18.01
# 3             0.0        24.69          24.69          24.69     18.01
# 4             0.0        24.69          24.69          24.69     18.01
# 5             0.0        24.69          24.69          24.69     18.01
# 6             0.0        24.69          24.69          24.69     18.01
# 7             0.0        24.69          24.69          24.69     18.01
# 8             0.0        26.20          26.20          26.20     17.64
# 9             0.0        27.55          27.55          27.55     17.27
#
#    Humidity.1  Humidity.2  Precipitation  Precipitation.1  Precipitation.2
# 0       18.01       18.01           0.01             0.01             0.01
# 1       18.01       18.01           0.01             0.01             0.01
# 2       18.01       18.01           0.01             0.01             0.01
# 3       18.01       18.01           0.01             0.01             0.01
# 4       18.01       18.01           0.01             0.01             0.01
# 5       18.01       18.01           0.01             0.01             0.01
# 6       18.01       18.01           0.01             0.01             0.01
# 7       18.01       18.01           0.01             0.01             0.01
# 8       17.64       17.64           0.01             0.01             0.01
# 9       17.27       17.27           0.02             0.02             0.02

# %% [markdown]
# ## Clean Dataset

# %% [markdown]
# ### Remove Dataset Outliers

# %%
# remove water data outliers
df['Waterlevel'] = df['Waterlevel'].clip(upper=18, lower=15, axis=0)
df['Waterlevel.1'] = df['Waterlevel.1'].clip(upper=17, lower=11, axis=0)
df['Waterlevel.2'] = df['Waterlevel.2'].clip(upper=17, lower=11, axis=0)
df['Waterlevel.3'] = df['Waterlevel.3'].clip(upper=25, lower=20, axis=0)

water_data = df[['Waterlevel', 'Waterlevel.1', 'Waterlevel.2', 'Waterlevel.3']]
plt.plot(water_data)
# Out:
# [<matplotlib.lines.Line2D at 0x17ff0c771f0>,
#  <matplotlib.lines.Line2D at 0x17ff0c771c0>,
#  <matplotlib.lines.Line2D at 0x17ff0c770d0>,
#  <matplotlib.lines.Line2D at 0x17ff0c76fe0>]

# %%
# remove weather data outliers
df['RF-Intensity'] = df['RF-Intensity'].clip(upper=35, lower=0, axis=0)
df['RF-Intensity.1'] = df['RF-Intensity.1'].clip(upper=35, lower=0, axis=0)
df[['Precipitation', 'Precipitation.1', 'Precipitation.2']] = df[['Precipitation', 'Precipitation.1', 'Precipitation.2']].clip(upper=10, lower=0, axis=0)

weather_data = df[['RF-Intensity', 'RF-Intensity.1', 'Temperature', 'Temperature.1',  'Temperature.2', 'Humidity', 'Humidity.1', 'Humidity.2', 'Precipitation', 'Precipitation.1', 'Precipitation.2']]
plt.plot(weather_data)
# Out:
# [<matplotlib.lines.Line2D at 0x17ffb349f00>,
#  <matplotlib.lines.Line2D at 0x17ffb349f30>,
#  <matplotlib.lines.Line2D at 0x17ffb34a020>,
#  <matplotlib.lines.Line2D at 0x17ffb34a110>,
#  <matplotlib.lines.Line2D at 0x17ffb34a200>,
#  <matplotlib.lines.Line2D at 0x17ffb34a2f0>,
#  <matplotlib.lines.Line2D at 0x17ffb2e0eb0>,
#  <matplotlib.lines.Line2D at 0x17ffb2e0dc0>,
#  <matplotlib.lines.Line2D at 0x17ffb2e0d30>,
#  <matplotlib.lines.Line2D at 0x17ffb16a410>,
#  <matplotlib.lines.Line2D at 0x17ffb16a110>]

# %%
# make time series stationary
df = df.diff()
df = df.drop(index=0)
df.shape
# Out:
# (59656, 15)

# %%
# drop all rows with zeros (no change at all)
df = df.loc[~(df==0).all(axis=1)]
df.shape
# Out:
# (59623, 15)

# %%
# smoothen time-series using moving average
df = df.rolling(window=48).mean()
df.dropna(inplace=True)
df.shape
# Out:
# (59576, 15)

# %%
# plot weather data
weather_data = df[['RF-Intensity', 'RF-Intensity.1', 'Temperature', 'Temperature.1']].to_numpy()
plt.plot(weather_data)
# Out:
# [<matplotlib.lines.Line2D at 0x17ffb3a7610>,
#  <matplotlib.lines.Line2D at 0x17f8419d090>,
#  <matplotlib.lines.Line2D at 0x17f8419d180>,
#  <matplotlib.lines.Line2D at 0x17f8419d270>]

# %%
# plot water data
water_data = df[['Humidity', 'Humidity.1', 'Precipitation', 'Precipitation.1']].to_numpy()
plt.plot(water_data)
# Out:
# [<matplotlib.lines.Line2D at 0x17f84224d00>,
#  <matplotlib.lines.Line2D at 0x17f84224d30>,
#  <matplotlib.lines.Line2D at 0x17f84224e20>,
#  <matplotlib.lines.Line2D at 0x17f84224f10>]

# %% [markdown]
# ## Normalized Dataset

# %%
# normalize water data
water_scaler = MinMaxScaler()
water_data = water_scaler.fit_transform(water_data)
plt.plot(water_data)
# Out:
# [<matplotlib.lines.Line2D at 0x17f8446ec80>,
#  <matplotlib.lines.Line2D at 0x17f8446ecb0>,
#  <matplotlib.lines.Line2D at 0x17f8446eda0>,
#  <matplotlib.lines.Line2D at 0x17f8446ee90>]

# %%
# normalize weather data
weather_scaler = MinMaxScaler()
weather_data = weather_scaler.fit_transform(weather_data)
plt.plot(weather_data)
# Out:
# [<matplotlib.lines.Line2D at 0x17f84515270>,
#  <matplotlib.lines.Line2D at 0x17f845152a0>,
#  <matplotlib.lines.Line2D at 0x17f84515390>,
#  <matplotlib.lines.Line2D at 0x17f84515480>]

# %% [markdown]
# ## Prepare Training Batches

# %%
# utilize rolling window to generate dataset
MAX_TOKENS = 168
window_size = MAX_TOKENS + 1
window_step = 72
series_len = len(weather_data) - window_size

weather_windows = np.array([weather_data[i:(i + window_size)] for i in range(0, series_len, window_step)])
print(weather_windows.shape)

water_windows = np.array([water_data[i:(i + window_size)] for i in range(0, series_len, window_step)])
print(water_windows.shape)
# Out:
# (826, 169, 4)
# (826, 169, 4)

# %%
# training dataset
X1_train = np.array([arr[:MAX_TOKENS] for arr in weather_windows[:578]])
X2_train = np.array([arr[:-1] for arr in water_windows[:578]])
Y_train = np.array([arr[1:] for arr in water_windows[:578]])

print(X1_train.shape)
print(X2_train.shape)
print(Y_train.shape)

# validation dataset
X1_val = np.array([arr[:MAX_TOKENS] for arr in weather_windows[578:702]])
X2_val = np.array([arr[:-1] for arr in water_windows[578:702]])
Y_val = np.array([arr[1:] for arr in water_windows[578:702]])

print(X1_val.shape)
print(X2_val.shape)
print(Y_val.shape)

# testing dataset
X1_test = np.array([arr[:MAX_TOKENS] for arr in weather_windows[702:]])
X2_test = np.array([arr[:-1] for arr in water_windows[702:]])
Y_test = np.array([arr[1:] for arr in water_windows[702:]])

print(X1_test.shape)
print(X2_test.shape)
print(Y_test.shape)
# Out:
# (578, 168, 4)
# (578, 168, 4)
# (578, 168, 4)
# (124, 168, 4)
# (124, 168, 4)
# (124, 168, 4)
# (124, 168, 4)
# (124, 168, 4)
# (124, 168, 4)

# %% [markdown]
# ## Build the Model

# %%
# Positional Encoding
def positional_encoding(length, depth):
    depth = depth / 2
    positions = np.arange(length)[:, np.newaxis]     # (seq, 1)
    depths = np.arange(depth)[np.newaxis, :]/depth   # (1, depth)

    angle_rates = 1 / (10000**depths)         # (1, depth)
    angle_rads = positions * angle_rates      # (pos, depth)

    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)],
        axis=-1) 

    return tf.cast(pos_encoding, dtype=tf.float32)


class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, d_model):
        super().__init__()
        self.d_model = d_model
        self.pos_encoding = positional_encoding(length=2048, depth=d_model)

    def call(self, x):
        length = tf.shape(x)[1]
        # This factor sets the relative scale of the positional encoding.
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x = x + self.pos_encoding[tf.newaxis, :length, :]
        return x

# layer test
pos_encoding = PositionalEmbedding(d_model=4)
encoding = pos_encoding(X1_test)
encoding.shape
# Out:
# TensorShape([124, 168, 4])

# %%
# Attention Layers

class BaseAttention(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
        self.layernorm = tf.keras.layers.LayerNormalization()
        self.add = tf.keras.layers.Add()
        
class CrossAttention(BaseAttention):
    def call(self, x, context):
        attn_output, attn_scores = self.mha(
            query=x,
            key=context,
            value=context,
            return_attention_scores=True)

        # Cache the attention scores for plotting later.
        self.last_attn_scores = attn_scores

        x = self.add([x, attn_output])
        x = self.layernorm(x)

        return x

# layer test
cross_attn = CrossAttention(num_heads=1, key_dim=4, dropout=0.1)
attn_scores = cross_attn(X2_test, X1_test)
print(attn_scores.shape)
    
class GlobalSelfAttention(BaseAttention):
    def call(self, x):
        attn_output = self.mha(
            query=x,
            value=x,
            key=x)
        x = self.add([x, attn_output])
        x = self.layernorm(x)
        return x
    
# layer test
global_attn = GlobalSelfAttention(num_heads=1, key_dim=4, dropout=0.1)
attn_scores = global_attn(X1_test)
print(attn_scores.shape)
    
class CausalSelfAttention(BaseAttention):
    def call(self, x):
        attn_output = self.mha(
            query=x,
            value=x,
            key=x,
            use_causal_mask=True)
        
        x = self.add([x, attn_output])
        x = self.layernorm(x)
        return x
    
# layer test
casual_attn = CausalSelfAttention(num_heads=1, key_dim=4, dropout=0.1)
attn_scores = casual_attn(X2_test)
print(attn_scores.shape)
# Out:
# (124, 168, 4)
# (124, 168, 4)
# (124, 168, 4)

# %%
# Feed Forward Layer

class FeedForward(tf.keras.layers.Layer):
    def __init__(self, d_model, dff, dropout_rate=0.1):
        super().__init__()
        self.seq = tf.keras.Sequential([
            tf.keras.layers.Dense(dff, activation='tanh'),
            tf.keras.layers.Dense(dff, activation='tanh'),
            tf.keras.layers.Dense(d_model, activation='tanh')
        ])
        self.add = tf.keras.layers.Add()
        self.layer_norm = tf.keras.layers.LayerNormalization()

    def call(self, x):
        x = self.add([x, self.seq(x)])
        x = self.layer_norm(x) 
        return x
    
# layer test
feed_forward = FeedForward(d_model=4, dff=512)
output = feed_forward(X2_test)
output.shape
# Out:
# TensorShape([124, 168, 4])

# %%
# Encoder Layer

class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self,*, d_model, dff, dropout_rate=0.1):
        super().__init__()
        self.self_attention = GlobalSelfAttention(
            num_heads=1,
            key_dim=d_model,
            dropout=dropout_rate)
        
        self.ffn = FeedForward(d_model, dff)

    def call(self, x):
        x = self.self_attention(x)
        x = self.ffn(x)
        return x
    
class Encoder(tf.keras.layers.Layer):
    def __init__(self, *, dff, d_model=4, dropout_rate=0.1):
        super().__init__()
        self.d_model = d_model
        self.pos_embedding = PositionalEmbedding(d_model=d_model)
        self.enc_layer = EncoderLayer(d_model=d_model, dff=dff, dropout_rate=dropout_rate)

    def call(self, x):
        x = self.pos_embedding(x)  # Shape `(batch_size, seq_len, d_model)`.
        x = self.enc_layer(x)
        return x  # Shape `(batch_size, seq_len, d_model)`.
    
# layer test
encoder = Encoder(dff=512)
output = encoder(X1_test)
output.shape
# Out:
# TensorShape([124, 168, 4])

# %%
# Decoder Layer

class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, *, d_model, dff, dropout_rate=0.1):
        super(DecoderLayer, self).__init__()
        self.causal_self_attention = CausalSelfAttention(
            num_heads=1,
            key_dim=d_model,
            dropout=dropout_rate)
        
        self.cross_attention = CrossAttention(
            num_heads=1,
            key_dim=3,
            dropout=dropout_rate)
        
        self.ffn = FeedForward(d_model, dff)

    def call(self, x, context):
        x = self.causal_self_attention(x=x)
        x = self.cross_attention(x=x, context=context)
        self.last_attn_scores = self.cross_attention.last_attn_scores  # Cache the last attention scores
        x = self.ffn(x)  
        return x
    
class Decoder(tf.keras.layers.Layer):
    def __init__(self, *, dff, d_model=4, dropout_rate=0.1):
        super(Decoder, self).__init__()
        self.d_model = d_model
        self.pos_embedding = PositionalEmbedding(d_model=d_model)
        self.dec_layer = DecoderLayer(d_model=d_model, dff=dff, dropout_rate=dropout_rate)
        self.last_attn_scores = None

    def call(self, x, context):
        x = self.pos_embedding(x)
        x = self.dec_layer(x, context)
        self.last_attn_scores = self.dec_layer.last_attn_scores

        return x

# layer test
decoder = Decoder(dff=512)
output = decoder(X2_test, X1_test)
output.shape
# Out:
# TensorShape([124, 168, 4])

# %%
# Transformer Model

class Transformer(tf.keras.Model):
    def __init__(self, *, dff, target_output_size, dropout_rate=0.1):
        super().__init__()
        self.encoder = Encoder(dff=dff, dropout_rate=dropout_rate)
        self.decoder = Decoder(dff=dff, dropout_rate=dropout_rate)
        self.final_layer = tf.keras.layers.Dense(target_output_size, activation='sigmoid')

    def call(self, inputs):
        # To use a Keras model with `.fit` you must pass all your inputs in the
        # first argument.
        context, x  = inputs
        
        context = self.encoder(context)

        x = self.decoder(x, context)  # (batch_size, target_len, d_model)

        # Final linear layer output.
        output = self.final_layer(x)  # (batch_size, target_len, target_vocab_size)

        try:
            # Drop the keras mask, so it doesn't scale the losses/metrics.
            # b/250038731
            del output._keras_mask
        except AttributeError:
            pass

        # Return the final output and the attention weights.
        return output
    
# test model
transformer = Transformer(dff=512, target_output_size=4)

output = transformer((X1_test, X2_test))
output.shape
# Out:
# TensorShape([124, 168, 4])

# %%
transformer.summary()
# Out:
# Model: "transformer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_1 (Encoder)         multiple                  267364
#
#  decoder_1 (Decoder)         multiple                  267433
#
#  dense_15 (Dense)            multiple                  20
#
# =================================================================
# Total params: 534817 (2.04 MB)
# Trainable params: 534817 (2.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import keras 

callback = keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', patience=3)

transformer.compile(
    loss=keras.losses.MeanSquaredError(),
    optimizer=keras.optimizers.Adam(),
    metrics=[keras.metrics.MeanAbsoluteError()])

transformer.fit(x=(X1_train, X2_train), y=Y_train, batch_size=128, epochs=100, validation_data=((X1_val, X2_val), Y_val), callbacks=[callback])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 14s 1s/step - loss: 0.0226 - mean_absolute_error: 0.1173 - val_loss: 0.0145 - val_mean_absolute_error: 0.0944
# Epoch 2/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0124 - mean_absolute_error: 0.0883 - val_loss: 0.0126 - val_mean_absolute_error: 0.0877
# Epoch 3/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0111 - mean_absolute_error: 0.0828 - val_loss: 0.0117 - val_mean_absolute_error: 0.0829
# Epoch 4/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0101 - mean_absolute_error: 0.0779 - val_loss: 0.0108 - val_mean_absolute_error: 0.0783
# Epoch 5/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0093 - mean_absolute_error: 0.0739 - val_loss: 0.0100 - val_mean_absolute_error: 0.0753
# Epoch 6/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0085 - mean_absolute_error: 0.0706 - val_loss: 0.0092 - val_mean_absolute_error: 0.0717
# Epoch 7/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0078 - mean_absolute_error: 0.0673 - val_loss: 0.0086 - val_mean_absolute_error: 0.0695
# Epoch 8/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0073 - mean_absolute_error: 0.0650 - val_loss: 0.0081 - val_mean_absolute_error: 0.0666
# Epoch 9/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0068 - mean_absolute_error: 0.0617 - val_loss: 0.0076 - val_mean_absolute_error: 0.0634
# Epoch 10/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0064 - mean_absolute_error: 0.0586 - val_loss: 0.0073 - val_mean_absolute_error: 0.0603
# Epoch 11/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0060 - mean_absolute_error: 0.0554 - val_loss: 0.0070 - val_mean_absolute_error: 0.0578
# Epoch 12/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0058 - mean_absolute_error: 0.0533 - val_loss: 0.0068 - val_mean_absolute_error: 0.0559
# Epoch 13/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0056 - mean_absolute_error: 0.0515 - val_loss: 0.0066 - val_mean_absolute_error: 0.0546
# Epoch 14/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0054 - mean_absolute_error: 0.0501 - val_loss: 0.0065 - val_mean_absolute_error: 0.0533
# Epoch 15/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0053 - mean_absolute_error: 0.0489 - val_loss: 0.0065 - val_mean_absolute_error: 0.0524
# Epoch 16/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0053 - mean_absolute_error: 0.0480 - val_loss: 0.0064 - val_mean_absolute_error: 0.0516
# Epoch 17/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0052 - mean_absolute_error: 0.0474 - val_loss: 0.0064 - val_mean_absolute_error: 0.0512
# Epoch 18/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0052 - mean_absolute_error: 0.0469 - val_loss: 0.0063 - val_mean_absolute_error: 0.0508
# Epoch 19/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0052 - mean_absolute_error: 0.0466 - val_loss: 0.0063 - val_mean_absolute_error: 0.0506
# Epoch 20/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0462 - val_loss: 0.0063 - val_mean_absolute_error: 0.0503
# Epoch 21/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0460 - val_loss: 0.0063 - val_mean_absolute_error: 0.0501
# Epoch 22/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0459 - val_loss: 0.0063 - val_mean_absolute_error: 0.0500
# Epoch 23/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0458 - val_loss: 0.0063 - val_mean_absolute_error: 0.0499
# Epoch 24/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.0051 - mean_absolute_error: 0.0457 - val_loss: 0.0063 - val_mean_absolute_error: 0.0498
# Epoch 25/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0457 - val_loss: 0.0062 - val_mean_absolute_error: 0.0498
# Epoch 26/100
# 5/5 [==============================] - 5s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0456 - val_loss: 0.0062 - val_mean_absolute_error: 0.0497
# Epoch 27/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0455 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 28/100
# 5/5 [==============================] - 9s 2s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 29/100
# 5/5 [==============================] - 8s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 30/100
# 5/5 [==============================] - 8s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 31/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0495
# Epoch 32/100
# 5/5 [==============================] - 8s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 33/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 34/100
# 5/5 [==============================] - 10s 2s/step - loss: 0.0051 - mean_absolute_error: 0.0454 - val_loss: 0.0062 - val_mean_absolute_error: 0.0494
# Epoch 35/100
# 5/5 [==============================] - 8s 2s/step - loss: 0.0051 - mean_absolute_error: 0.0453 - val_loss: 0.0062 - val_mean_absolute_error: 0.0496
# Epoch 36/100
# 5/5 [==============================] - 6s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0453 - val_loss: 0.0062 - val_mean_absolute_error: 0.0494
# Epoch 37/100
# 5/5 [==============================] - 7s 1s/step - loss: 0.0051 - mean_absolute_error: 0.0453 - val_loss: 0.0062 - val_mean_absolute_error: 0.0495

# %% [markdown]
# ## Test the Model

# %%
# measure accuracy
from sklearn.metrics import mean_absolute_error

pred = transformer.predict((X1_test, X2_test), verbose=None)
mean_absolute_error(y_true=np.reshape(Y_test, (-1, 4)), y_pred=np.reshape(pred, (-1, 4)))
# Out:
# 0.04946705838480697

# %%
def make_predictions(index):
    context = X1_test[index]
    target = X2_test[index][:72]
    print(context.shape)
    
    for i in range(MAX_TOKENS - 72):
        y_pred = transformer.predict(x=(np.array([context]), np.array([target])), verbose=None)
        target = np.vstack((target, np.array([y_pred[0][-1]])))
    
    print(target.shape)
    plt.plot(target)

# %%
make_predictions(0)
# Out:
# (168, 4)
# (168, 4)

# %%
plt.plot(Y_test[0])
# Out:
# [<matplotlib.lines.Line2D at 0x17f99a09d20>,
#  <matplotlib.lines.Line2D at 0x17f99a09a20>,
#  <matplotlib.lines.Line2D at 0x17f99a0aa70>,
#  <matplotlib.lines.Line2D at 0x17f99a0b0a0>]

# %%
make_predictions(50)
# Out:
# (168, 4)
# (168, 4)

# %%
make_predictions(85)
# Out:
# (168, 4)
# (168, 4)

# %%
plt.plot(Y_test[50])
# Out:
# [<matplotlib.lines.Line2D at 0x17f9bb4a7d0>,
#  <matplotlib.lines.Line2D at 0x17f9bb483d0>,
#  <matplotlib.lines.Line2D at 0x17f9bb4b0a0>,
#  <matplotlib.lines.Line2D at 0x17f9bb4ace0>]
